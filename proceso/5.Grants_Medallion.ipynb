# %% [markdown]
# ## 5. Grants_Medallion
#
# Asigna permisos Unity Catalog sobre el catalogo de futbol.

# %%
# %sql
GRANT USE CATALOG ON CATALOG football_dev TO `proyecto_smartdata1@outlook.com`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA football_dev.bronze TO `proyecto_smartdata1@outlook.com`;
GRANT USE SCHEMA ON SCHEMA football_dev.silver TO `proyecto_smartdata1@outlook.com`;
GRANT USE SCHEMA ON SCHEMA football_dev.gold TO `proyecto_smartdata1@outlook.com`;

GRANT USE SCHEMA ON SCHEMA football_dev.bronze TO `DEs`;
GRANT USE SCHEMA ON SCHEMA football_dev.silver TO `DEs`;
GRANT USE SCHEMA ON SCHEMA football_dev.gold TO `DEs`;

# %%
# %sql
GRANT SELECT ON TABLE football_dev.bronze.leagues TO `proyecto_smartdata1@outlook.com`;
GRANT SELECT ON TABLE football_dev.bronze.matches TO `proyecto_smartdata1@outlook.com`;
GRANT SELECT ON TABLE football_dev.bronze.clubs TO `proyecto_smartdata1@outlook.com`;
GRANT SELECT ON TABLE football_dev.silver.matches_transformed TO `proyecto_smartdata1@outlook.com`;
GRANT SELECT ON TABLE football_dev.gold.season_stats TO `proyecto_smartdata1@outlook.com`;

# %%
# %sql
GRANT CREATE TABLE ON SCHEMA football_dev.bronze TO `proyecto_smartdata1@outlook.com`;
